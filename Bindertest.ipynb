# %% [markdown]
# # Introduksjon til relativistisk kvantefeltteori
#
# I denne leksjonen skal du lære alt du trenger for å kunne studere kvantefeltteori på masternivå. Ingen forkunnskaper trengs! Start med å se denne videoen

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('ATcrrzJFtBY', width=600, height=500)

# %% [markdown]
# Nå som du har lært den første teorien, så starter vi med dirac-likningen.

# %% [markdown]
# $$ (i\gamma_{\mu}\partial^{\mu}-m)\psi=0 $$

# %% [markdown]
# Siden denne likningen forklarer seg selv, blir det etterlatt til leseren å bevise denne formelen i form av en oppgave. Under kan du prøve å simulere et fermions bølgefunksjon i vakuum

# %%
from pylab import *
print("Dette er en simulering av et fermion")
# Out:
# Dette er en simulering av et fermion

# %%
# Prøv å simulere selv i denne boksen.
